# %% [markdown]
# # Analyse the UNESCO Thesaurus
# Get the number of concepts and the depth of the ontology
#
# It is important to have rdflib, SPARQLWrapper, pandas, and numpy
# * pip install rdflib
# * pip install SPARQLWrapper
# * pip install pandas
# * pip install numpy
#
# Download the lastest version of the Unesco Thesaurus from http://vocabularies.unesco.org/browser/thesaurus/en/

# %%
from rdflib import Graph
from rdflib.namespace import RDFS
from rdflib import URIRef
import rdflib
import json
from collections import deque
import numpy as np

# %%
input_file = "unesco-thesaurus.rdf"
g = Graph()
g.parse(input_file)
# Out:
# <Graph identifier=N11d2a993a4474c3e80029abb53e72462 (<class 'rdflib.graph.Graph'>)>

# %%
qres = g.query(
    """SELECT DISTINCT ?a
       WHERE {
          # ?a a skos:Concept .
       }""")
topics = dict()
for row in qres:
#     print("%s" % row)
    topics[row[0]] = True
    
print("Number of concepts: {}".format(len(topics)))
# Out:
# Number of concepts: 4436

# %%
qres = g.query(
    """SELECT DISTINCT ?a ?b
       WHERE {
          # ?a skos:broader ?b .
          # ?a a skos:Concept
       }""")

broaders = dict()
narrowers = dict()
for row in qres:
    if row[0] not in broaders:
        broaders[row[0]] = list()
    broaders[row[0]].append(row[1])
    if row[1] not in narrowers:
        narrowers[row[1]] = list()
    narrowers[row[1]].append(row[0])

# %%
unhier = broaders
concepts = topics
for concept, value in concepts.items():
    queue = deque() 
    max_depth = value
    queue.append({"t":concept,"d":value})
    while len(queue) > 0:
        dequeued = queue.popleft()
        if dequeued["t"] in unhier:
            broads = unhier[dequeued["t"]]
            new_depth = dequeued["d"]+1
            if new_depth > max_depth:
                max_depth = new_depth
            for broader in broads:
                queue.append({"t":broader,"d":dequeued["d"]+1})
    
    concepts[concept] = max_depth

# %%
import pandas as pd
list_of_depths = pd.DataFrame.from_dict(concepts, orient='index', columns=['depth'])

# %%
list_of_depths.sort_values('depth', inplace=True, ascending=False)
print("Concepts are ranked by maximum depth")
list_of_depths.head(20)
# Out:
# Concepts are ranked by maximum depth
#                                                    depth
# http://vocabularies.unesco.org/thesaurus/concep...     6
# http://vocabularies.unesco.org/thesaurus/concep...     6
# http://vocabularies.unesco.org/thesaurus/concep...     6
# http://vocabularies.unesco.org/thesaurus/concep...     6
# http://vocabularies.unesco.org/thesaurus/concep...     6
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5
# http://vocabularies.unesco.org/thesaurus/concep...     5

# %%
print("If results are showed here, it means that one concept can have more than one parent: polyhierarchical")
for key, broad in broaders.items():
    #print(len(broad))
    if (len(broad) > 1):
        print(key, broad)
# Out:
# If results are showed here, it means that one concept can have more than one parent: polyhierarchical
# http://vocabularies.unesco.org/thesaurus/concept17085 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept7367 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept3557'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept956')]
# http://vocabularies.unesco.org/thesaurus/concept848 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept918 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept864 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept826')]
# http://vocabularies.unesco.org/thesaurus/concept788 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept691 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747')]
# http://vocabularies.unesco.org/thesaurus/concept907 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954')]
# http://vocabularies.unesco.org/thesaurus/concept721 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept953')]
# http://vocabularies.unesco.org/thesaurus/concept766 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept791'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965')]
# http://vocabularies.unesco.org/thesaurus/concept834 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850')]
# http://vocabularies.unesco.org/thesaurus/concept773 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept748 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept816 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept867')]
# http://vocabularies.unesco.org/thesaurus/concept844 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17064')]
# http://vocabularies.unesco.org/thesaurus/concept885 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960')]
# http://vocabularies.unesco.org/thesaurus/concept897 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954')]
# http://vocabularies.unesco.org/thesaurus/concept889 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept895'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept14720 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept807 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept948'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947')]
# http://vocabularies.unesco.org/thesaurus/concept804 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept719 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept951'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705')]
# http://vocabularies.unesco.org/thesaurus/concept829 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821')]
# http://vocabularies.unesco.org/thesaurus/concept746 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept797 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept890 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942')]
# http://vocabularies.unesco.org/thesaurus/concept859 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept888 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954')]
# http://vocabularies.unesco.org/thesaurus/concept756 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept727 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955')]
# http://vocabularies.unesco.org/thesaurus/concept870 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850')]
# http://vocabularies.unesco.org/thesaurus/concept818 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept952')]
# http://vocabularies.unesco.org/thesaurus/concept915 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept835 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942')]
# http://vocabularies.unesco.org/thesaurus/concept814 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942')]
# http://vocabularies.unesco.org/thesaurus/concept836 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept919 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17064'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942')]
# http://vocabularies.unesco.org/thesaurus/concept14426 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932')]
# http://vocabularies.unesco.org/thesaurus/concept826 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850')]
# http://vocabularies.unesco.org/thesaurus/concept745 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept953'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept729')]
# http://vocabularies.unesco.org/thesaurus/concept702 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697')]
# http://vocabularies.unesco.org/thesaurus/concept853 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept929 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954')]
# http://vocabularies.unesco.org/thesaurus/concept923 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928')]
# http://vocabularies.unesco.org/thesaurus/concept4785 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept895'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept704 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept950'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept921 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept717 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept778 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept741 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept950'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept772 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept769'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966')]
# http://vocabularies.unesco.org/thesaurus/concept764 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17064')]
# http://vocabularies.unesco.org/thesaurus/concept806 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept791')]
# http://vocabularies.unesco.org/thesaurus/concept731 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept722 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept951'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept739 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740')]
# http://vocabularies.unesco.org/thesaurus/concept738 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept950'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960')]
# http://vocabularies.unesco.org/thesaurus/concept846 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932')]
# http://vocabularies.unesco.org/thesaurus/concept783 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept861 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept877 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept819'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept701 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697')]
# http://vocabularies.unesco.org/thesaurus/concept820 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept743 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept749 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept724 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept729'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept953'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept725 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept967')]
# http://vocabularies.unesco.org/thesaurus/concept927 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938')]
# http://vocabularies.unesco.org/thesaurus/concept710 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697')]
# http://vocabularies.unesco.org/thesaurus/concept781 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept769')]
# http://vocabularies.unesco.org/thesaurus/concept14609 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept956'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept3557')]
# http://vocabularies.unesco.org/thesaurus/concept882 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept952'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868')]
# http://vocabularies.unesco.org/thesaurus/concept759 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept690 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept967'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740')]
# http://vocabularies.unesco.org/thesaurus/concept784 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept769')]
# http://vocabularies.unesco.org/thesaurus/concept10480 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept3557'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept742 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740')]
# http://vocabularies.unesco.org/thesaurus/concept847 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept867')]
# http://vocabularies.unesco.org/thesaurus/concept874 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept902 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934')]
# http://vocabularies.unesco.org/thesaurus/concept838 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept833 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850')]
# http://vocabularies.unesco.org/thesaurus/concept709 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept950')]
# http://vocabularies.unesco.org/thesaurus/concept875 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept713 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept922 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954')]
# http://vocabularies.unesco.org/thesaurus/concept755 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept776 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept948')]
# http://vocabularies.unesco.org/thesaurus/concept744 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747')]
# http://vocabularies.unesco.org/thesaurus/concept8621 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942')]
# http://vocabularies.unesco.org/thesaurus/concept17084 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept4239 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept714 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept967'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept869 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept951'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept867')]
# http://vocabularies.unesco.org/thesaurus/concept841 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept819'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept920 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938')]
# http://vocabularies.unesco.org/thesaurus/concept795 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept815 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept826'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept917 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928')]
# http://vocabularies.unesco.org/thesaurus/concept803 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept794 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept948'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800')]
# http://vocabularies.unesco.org/thesaurus/concept842 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept952'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965')]
# http://vocabularies.unesco.org/thesaurus/concept785 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept730 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept951'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705')]
# http://vocabularies.unesco.org/thesaurus/concept914 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept912 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept949'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept761 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept769'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966')]
# http://vocabularies.unesco.org/thesaurus/concept16993 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17064'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868')]
# http://vocabularies.unesco.org/thesaurus/concept916 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928')]
# http://vocabularies.unesco.org/thesaurus/concept810 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850')]
# http://vocabularies.unesco.org/thesaurus/concept865 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941')]
# http://vocabularies.unesco.org/thesaurus/concept13963 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954')]
# http://vocabularies.unesco.org/thesaurus/concept799 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept768 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept8623 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept774 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept693 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept14719 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept775 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept893 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928')]
# http://vocabularies.unesco.org/thesaurus/concept823 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept851 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821')]
# http://vocabularies.unesco.org/thesaurus/concept910 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept12233 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept867')]
# http://vocabularies.unesco.org/thesaurus/concept894 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938')]
# http://vocabularies.unesco.org/thesaurus/concept879 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept826')]
# http://vocabularies.unesco.org/thesaurus/concept9796 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept792 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept769')]
# http://vocabularies.unesco.org/thesaurus/concept789 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept832 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept825 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept905 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934')]
# http://vocabularies.unesco.org/thesaurus/concept909 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept735 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept824 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept695 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept839 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942')]
# http://vocabularies.unesco.org/thesaurus/concept787 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept791'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966')]
# http://vocabularies.unesco.org/thesaurus/concept12132 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept3557'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942')]
# http://vocabularies.unesco.org/thesaurus/concept801 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947')]
# http://vocabularies.unesco.org/thesaurus/concept857 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept826')]
# http://vocabularies.unesco.org/thesaurus/concept845 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17064'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept906 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept872 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept819')]
# http://vocabularies.unesco.org/thesaurus/concept908 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938')]
# http://vocabularies.unesco.org/thesaurus/concept696 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept967'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747')]
# http://vocabularies.unesco.org/thesaurus/concept802 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept926 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept898 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept700 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept951'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705')]
# http://vocabularies.unesco.org/thesaurus/concept925 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept840 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept826'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept760 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept716 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept796 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept866 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept911 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept949'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept896 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept763 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept948'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947')]
# http://vocabularies.unesco.org/thesaurus/concept750 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept892 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept758 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept733 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936')]
# http://vocabularies.unesco.org/thesaurus/concept712 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747')]
# http://vocabularies.unesco.org/thesaurus/concept849 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept720 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept811 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept699 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697')]
# http://vocabularies.unesco.org/thesaurus/concept854 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept10481 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept956'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept3557'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept779 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept873 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932')]
# http://vocabularies.unesco.org/thesaurus/concept694 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept830 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept689 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept953'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept729')]
# http://vocabularies.unesco.org/thesaurus/concept692 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept860 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932')]
# http://vocabularies.unesco.org/thesaurus/concept817 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept932'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept868')]
# http://vocabularies.unesco.org/thesaurus/concept737 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept718 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept729'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept953')]
# http://vocabularies.unesco.org/thesaurus/concept723 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705')]
# http://vocabularies.unesco.org/thesaurus/concept862 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept826'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept790 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept769')]
# http://vocabularies.unesco.org/thesaurus/concept751 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740')]
# http://vocabularies.unesco.org/thesaurus/concept703 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616')]
# http://vocabularies.unesco.org/thesaurus/concept707 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697')]
# http://vocabularies.unesco.org/thesaurus/concept891 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept895'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept878 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept863 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept883 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept852 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept706 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept729')]
# http://vocabularies.unesco.org/thesaurus/concept726 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept740'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964')]
# http://vocabularies.unesco.org/thesaurus/concept698 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept1616'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697')]
# http://vocabularies.unesco.org/thesaurus/concept757 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept957'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800')]
# http://vocabularies.unesco.org/thesaurus/concept17028 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821')]
# http://vocabularies.unesco.org/thesaurus/concept762 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept791')]
# http://vocabularies.unesco.org/thesaurus/concept793 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept957'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966')]
# http://vocabularies.unesco.org/thesaurus/concept7343 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept904 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928')]
# http://vocabularies.unesco.org/thesaurus/concept858 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept867')]
# http://vocabularies.unesco.org/thesaurus/concept8622 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept17058 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept5114 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100')]
# http://vocabularies.unesco.org/thesaurus/concept900 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept949'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935')]
# http://vocabularies.unesco.org/thesaurus/concept782 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept728 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17100'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955')]
# http://vocabularies.unesco.org/thesaurus/concept711 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept955'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept747'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961')]
# http://vocabularies.unesco.org/thesaurus/concept708 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept950')]
# http://vocabularies.unesco.org/thesaurus/concept827 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept806'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
# http://vocabularies.unesco.org/thesaurus/concept736 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept951'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705')]
# http://vocabularies.unesco.org/thesaurus/concept777 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept769'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966')]
# http://vocabularies.unesco.org/thesaurus/concept881 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept843 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept960')]
# http://vocabularies.unesco.org/thesaurus/concept770 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept957'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept948'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800')]
# http://vocabularies.unesco.org/thesaurus/concept924 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965')]
# http://vocabularies.unesco.org/thesaurus/concept880 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept819'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept837 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept819'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept933')]
# http://vocabularies.unesco.org/thesaurus/concept876 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept961'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept850')]
# http://vocabularies.unesco.org/thesaurus/concept734 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept967'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept697'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034')]
# http://vocabularies.unesco.org/thesaurus/concept828 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept941'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept821')]
# http://vocabularies.unesco.org/thesaurus/concept765 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept936'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept767')]
# http://vocabularies.unesco.org/thesaurus/concept715 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept950'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept964'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept705')]
# http://vocabularies.unesco.org/thesaurus/concept903 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept938'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899')]
# http://vocabularies.unesco.org/thesaurus/concept17059 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept899'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept954')]
# http://vocabularies.unesco.org/thesaurus/concept913 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept928'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept942'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept965'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept935'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept934')]
# http://vocabularies.unesco.org/thesaurus/concept771 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept947'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept948'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800')]
# http://vocabularies.unesco.org/thesaurus/concept805 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept966'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept800'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept957')]
# http://vocabularies.unesco.org/thesaurus/concept855 [rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept17034'), rdflib.term.URIRef('http://vocabularies.unesco.org/thesaurus/concept856')]
