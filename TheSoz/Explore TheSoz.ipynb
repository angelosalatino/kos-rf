# %% [markdown]
# # Analyse TheSoz
# Get the number of concepts and the depth of the ontology
#
# It is important to have rdflib, SPARQLWrapper, pandas, and numpy
# * pip install rdflib
# * pip install SPARQLWrapper
# * pip install pandas
# * pip install numpy
#
# Download the lastest version of TheSoz from http://lod.gesis.org/download-thesoz.html

# %%
from rdflib import Graph
from rdflib.namespace import RDFS
from rdflib import URIRef
import rdflib
import json
from collections import deque
import numpy as np
import pandas as pd

# %%
input_file = "thesoz-komplett.xml"
g = Graph()
g.parse(input_file)
# Out:
# <Graph identifier=Nb8397126b45e41ae8f1c2fc1b012ef92 (<class 'rdflib.graph.Graph'>)>

# %%
qres = g.query(
    """PREFIX skos:<http://www.w3.org/2004/02/skos/core#>
       SELECT DISTINCT ?a
       WHERE {
          # ?a a skos:Concept .
       }""")


topics = dict()
for row in qres:
    topics[row[0]] = True
    
print("Number of concepts: {}".format(len(topics)))
# Out:
# Number of concepts: 8223

# %%
qres = g.query(
    """PREFIX skos:<http://www.w3.org/2004/02/skos/core#>
       SELECT DISTINCT ?a ?b
       WHERE {
          # ?a skos:broader ?b .
       }""")

broaders = dict()
narrowers = dict()
for row in qres:
    if row[0] not in broaders:
        broaders[row[0]] = list()
    broaders[row[0]].append(row[1])
    if row[1] not in narrowers:
        narrowers[row[1]] = list()
    narrowers[row[1]].append(row[0])

# %%
unhier = broaders
concepts = topics
for concept, value in concepts.items():
    queue = deque() 
    max_depth = value
    queue.append({"t":concept,"d":value})
    while len(queue) > 0:
        dequeued = queue.popleft()
        if dequeued["t"] in unhier:
            broads = unhier[dequeued["t"]]
            new_depth = dequeued["d"]+1
            if new_depth > max_depth:
                max_depth = new_depth
            for broader in broads:
                queue.append({"t":broader,"d":dequeued["d"]+1})
    
    concepts[concept] = max_depth

# %%
list_of_depths = pd.DataFrame.from_dict(concepts, orient='index', columns=['depth'])
list_of_depths.sort_values('depth', inplace=True, ascending=False)

# %%
print("Concepts are ranked by maximum depth")
list_of_depths.head(20)
# Out:
# Concepts are ranked by maximum depth
#                                              depth
# http://lod.gesis.org/thesoz/concept_10061648     6
# http://lod.gesis.org/thesoz/concept_10058142     6
# http://lod.gesis.org/thesoz/concept_10035238     6
# http://lod.gesis.org/thesoz/concept_10036183     6
# http://lod.gesis.org/thesoz/concept_10046475     6
# http://lod.gesis.org/thesoz/concept_10082204     6
# http://lod.gesis.org/thesoz/concept_10042743     6
# http://lod.gesis.org/thesoz/concept_10061649     6
# http://lod.gesis.org/thesoz/concept_10040091     6
# http://lod.gesis.org/thesoz/concept_10050512     6
# http://lod.gesis.org/thesoz/concept_10046476     6
# http://lod.gesis.org/thesoz/concept_10056980     6
# http://lod.gesis.org/thesoz/concept_10050078     6
# http://lod.gesis.org/thesoz/concept_10094082     6
# http://lod.gesis.org/thesoz/concept_10035207     6
# http://lod.gesis.org/thesoz/concept_10064824     5
# http://lod.gesis.org/thesoz/concept_10041822     5
# http://lod.gesis.org/thesoz/concept_10043441     5
# http://lod.gesis.org/thesoz/concept_10082893     5
# http://lod.gesis.org/thesoz/concept_10062839     5

# %%
for k, v in broaders.items(): 
    if len(v) > 1: 
        print("{} has {} parents".format(k, len(v)))
# Out:
# http://lod.gesis.org/thesoz/concept_10051649 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051733 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035652 has 3 parents
# http://lod.gesis.org/thesoz/concept_10034970 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038178 has 2 parents
# http://lod.gesis.org/thesoz/concept_10093747 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043347 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047976 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040512 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042365 has 3 parents
# http://lod.gesis.org/thesoz/concept_10043826 has 3 parents
# http://lod.gesis.org/thesoz/concept_10036205 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043309 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035657 has 3 parents
# http://lod.gesis.org/thesoz/concept_10044122 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039808 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035660 has 3 parents
# http://lod.gesis.org/thesoz/concept_10036109 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051390 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040071 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035558 has 2 parents
# http://lod.gesis.org/thesoz/concept_10060798 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045424 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037664 has 2 parents
# http://lod.gesis.org/thesoz/concept_10054756 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043680 has 2 parents
# http://lod.gesis.org/thesoz/concept_10053082 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042355 has 2 parents
# http://lod.gesis.org/thesoz/concept_10053053 has 2 parents
# http://lod.gesis.org/thesoz/concept_10062839 has 2 parents
# http://lod.gesis.org/thesoz/concept_10070030 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051195 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035555 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042349 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036060 has 4 parents
# http://lod.gesis.org/thesoz/concept_10049739 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042311 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043817 has 2 parents
# http://lod.gesis.org/thesoz/concept_10057838 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051747 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034673 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042682 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047954 has 2 parents
# http://lod.gesis.org/thesoz/concept_10069097 has 2 parents
# http://lod.gesis.org/thesoz/concept_10052026 has 2 parents
# http://lod.gesis.org/thesoz/concept_10052028 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037672 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040041 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035874 has 4 parents
# http://lod.gesis.org/thesoz/concept_10039771 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035649 has 3 parents
# http://lod.gesis.org/thesoz/concept_10034606 has 4 parents
# http://lod.gesis.org/thesoz/concept_10049708 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038057 has 6 parents
# http://lod.gesis.org/thesoz/concept_10038128 has 3 parents
# http://lod.gesis.org/thesoz/concept_10040805 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042330 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040272 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044183 has 2 parents
# http://lod.gesis.org/thesoz/concept_10055264 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049147 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035648 has 3 parents
# http://lod.gesis.org/thesoz/concept_10035400 has 2 parents
# http://lod.gesis.org/thesoz/concept_10054902 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035651 has 3 parents
# http://lod.gesis.org/thesoz/concept_10035871 has 3 parents
# http://lod.gesis.org/thesoz/concept_10040440 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038087 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042327 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042353 has 3 parents
# http://lod.gesis.org/thesoz/concept_10046489 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036266 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045907 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042356 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045286 has 2 parents
# http://lod.gesis.org/thesoz/concept_10059586 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041558 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036801 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041673 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035911 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043314 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035868 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035865 has 4 parents
# http://lod.gesis.org/thesoz/concept_10042352 has 3 parents
# http://lod.gesis.org/thesoz/concept_10082367 has 2 parents
# http://lod.gesis.org/thesoz/concept_10063251 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036245 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039381 has 3 parents
# http://lod.gesis.org/thesoz/concept_10034687 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035867 has 4 parents
# http://lod.gesis.org/thesoz/concept_10042323 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042348 has 3 parents
# http://lod.gesis.org/thesoz/concept_10040222 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035877 has 4 parents
# http://lod.gesis.org/thesoz/concept_10051113 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034828 has 2 parents
# http://lod.gesis.org/thesoz/concept_10050424 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042326 has 2 parents
# http://lod.gesis.org/thesoz/concept_10058607 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047850 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044630 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042325 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042338 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042333 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042309 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042324 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042357 has 3 parents
# http://lod.gesis.org/thesoz/concept_10035872 has 3 parents
# http://lod.gesis.org/thesoz/concept_10046021 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040169 has 3 parents
# http://lod.gesis.org/thesoz/concept_10041885 has 3 parents
# http://lod.gesis.org/thesoz/concept_10039108 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035914 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035876 has 3 parents
# http://lod.gesis.org/thesoz/concept_10036142 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042366 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042364 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042361 has 3 parents
# http://lod.gesis.org/thesoz/concept_10036847 has 3 parents
# http://lod.gesis.org/thesoz/concept_10058883 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039809 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042759 has 2 parents
# http://lod.gesis.org/thesoz/concept_10057301 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046842 has 2 parents
# http://lod.gesis.org/thesoz/concept_10071896 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039021 has 3 parents
# http://lod.gesis.org/thesoz/concept_10043437 has 3 parents
# http://lod.gesis.org/thesoz/concept_10051732 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042320 has 3 parents
# http://lod.gesis.org/thesoz/concept_10044176 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043438 has 4 parents
# http://lod.gesis.org/thesoz/concept_10036478 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036737 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036426 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040699 has 2 parents
# http://lod.gesis.org/thesoz/concept_10069444 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035892 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034368 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047849 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037341 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037403 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035653 has 3 parents
# http://lod.gesis.org/thesoz/concept_10049262 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042322 has 3 parents
# http://lod.gesis.org/thesoz/concept_10051672 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035324 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043295 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047084 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037253 has 2 parents
# http://lod.gesis.org/thesoz/concept_10048485 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035656 has 3 parents
# http://lod.gesis.org/thesoz/concept_10035900 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035907 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047898 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041727 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045466 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034956 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042416 has 3 parents
# http://lod.gesis.org/thesoz/concept_10038050 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035207 has 2 parents
# http://lod.gesis.org/thesoz/concept_10048042 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040797 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038099 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044063 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036945 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042362 has 3 parents
# http://lod.gesis.org/thesoz/concept_10050079 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035560 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043684 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035663 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047897 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039022 has 3 parents
# http://lod.gesis.org/thesoz/concept_10036470 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036669 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039838 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049548 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035561 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037011 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038054 has 4 parents
# http://lod.gesis.org/thesoz/concept_10041043 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042312 has 2 parents
# http://lod.gesis.org/thesoz/concept_10052544 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040174 has 3 parents
# http://lod.gesis.org/thesoz/concept_10045120 has 2 parents
# http://lod.gesis.org/thesoz/concept_10082893 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042347 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047846 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042318 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035212 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034484 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035858 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042970 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036477 has 3 parents
# http://lod.gesis.org/thesoz/concept_10047896 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049921 has 2 parents
# http://lod.gesis.org/thesoz/concept_10058142 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039969 has 3 parents
# http://lod.gesis.org/thesoz/concept_10044376 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042336 has 2 parents
# http://lod.gesis.org/thesoz/concept_10055820 has 3 parents
# http://lod.gesis.org/thesoz/concept_10043625 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036306 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042360 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042248 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042314 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036366 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040744 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038597 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038842 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040001 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034706 has 2 parents
# http://lod.gesis.org/thesoz/concept_10052381 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043329 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044177 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035659 has 3 parents
# http://lod.gesis.org/thesoz/concept_10034681 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035208 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034451 has 3 parents
# http://lod.gesis.org/thesoz/concept_10041440 has 4 parents
# http://lod.gesis.org/thesoz/concept_10036698 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035975 has 2 parents
# http://lod.gesis.org/thesoz/concept_10056980 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035393 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041880 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045288 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039716 has 2 parents
# http://lod.gesis.org/thesoz/concept_10052925 has 3 parents
# http://lod.gesis.org/thesoz/concept_10043839 has 4 parents
# http://lod.gesis.org/thesoz/concept_10035384 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047198 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042762 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038088 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042341 has 2 parents
# http://lod.gesis.org/thesoz/concept_10053247 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036803 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043439 has 3 parents
# http://lod.gesis.org/thesoz/concept_10045641 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037626 has 2 parents
# http://lod.gesis.org/thesoz/concept_10062881 has 2 parents
# http://lod.gesis.org/thesoz/concept_10064227 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037345 has 3 parents
# http://lod.gesis.org/thesoz/concept_10038334 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041257 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035325 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043097 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042079 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037621 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044466 has 4 parents
# http://lod.gesis.org/thesoz/concept_10043676 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042346 has 3 parents
# http://lod.gesis.org/thesoz/concept_10040255 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043708 has 3 parents
# http://lod.gesis.org/thesoz/concept_10036848 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045393 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036870 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042308 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042310 has 3 parents
# http://lod.gesis.org/thesoz/concept_10064291 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035654 has 3 parents
# http://lod.gesis.org/thesoz/concept_10036804 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040398 has 3 parents
# http://lod.gesis.org/thesoz/concept_10034461 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035402 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037296 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047848 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034660 has 2 parents
# http://lod.gesis.org/thesoz/concept_10048278 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043934 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035423 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040267 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035347 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047847 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042215 has 2 parents
# http://lod.gesis.org/thesoz/concept_10050512 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045518 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034514 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042313 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045971 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038600 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038112 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043768 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035869 has 4 parents
# http://lod.gesis.org/thesoz/concept_10041849 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035231 has 4 parents
# http://lod.gesis.org/thesoz/concept_10042343 has 2 parents
# http://lod.gesis.org/thesoz/concept_10055845 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036820 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047457 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036207 has 2 parents
# http://lod.gesis.org/thesoz/concept_10048848 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042358 has 2 parents
# http://lod.gesis.org/thesoz/concept_10048597 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034942 has 2 parents
# http://lod.gesis.org/thesoz/concept_10056684 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040528 has 2 parents
# http://lod.gesis.org/thesoz/concept_10052457 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041639 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042359 has 3 parents
# http://lod.gesis.org/thesoz/concept_10046572 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034633 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041115 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042315 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034450 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034674 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037284 has 3 parents
# http://lod.gesis.org/thesoz/concept_10043134 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040424 has 2 parents
# http://lod.gesis.org/thesoz/concept_10065796 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049572 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040979 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042520 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044181 has 2 parents
# http://lod.gesis.org/thesoz/concept_10059587 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037391 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037105 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039751 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037393 has 3 parents
# http://lod.gesis.org/thesoz/concept_10045369 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034685 has 2 parents
# http://lod.gesis.org/thesoz/concept_10059826 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045289 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040091 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042734 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045437 has 3 parents
# http://lod.gesis.org/thesoz/concept_10047616 has 3 parents
# http://lod.gesis.org/thesoz/concept_10035029 has 4 parents
# http://lod.gesis.org/thesoz/concept_10043310 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036075 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040906 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042372 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047910 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042354 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038055 has 4 parents
# http://lod.gesis.org/thesoz/concept_10034452 has 3 parents
# http://lod.gesis.org/thesoz/concept_10041368 has 3 parents
# http://lod.gesis.org/thesoz/concept_10041827 has 2 parents
# http://lod.gesis.org/thesoz/concept_10053652 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038025 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041879 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035655 has 3 parents
# http://lod.gesis.org/thesoz/concept_10041461 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045427 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035751 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034825 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042351 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034679 has 2 parents
# http://lod.gesis.org/thesoz/concept_10048219 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051748 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042331 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035766 has 2 parents
# http://lod.gesis.org/thesoz/concept_10070723 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043679 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035245 has 2 parents
# http://lod.gesis.org/thesoz/concept_10053541 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042368 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042344 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038508 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040040 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034647 has 3 parents
# http://lod.gesis.org/thesoz/concept_10040074 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041645 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041874 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043469 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045517 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036043 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041878 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047977 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049802 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036037 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039242 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034680 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035559 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039812 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046568 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043483 has 2 parents
# http://lod.gesis.org/thesoz/concept_10048285 has 2 parents
# http://lod.gesis.org/thesoz/concept_10073299 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036053 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035875 has 4 parents
# http://lod.gesis.org/thesoz/concept_10045621 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039762 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041457 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049359 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034634 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046325 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035658 has 3 parents
# http://lod.gesis.org/thesoz/concept_10035650 has 3 parents
# http://lod.gesis.org/thesoz/concept_10054852 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046569 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042340 has 2 parents
# http://lod.gesis.org/thesoz/concept_10093744 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036901 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046017 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049360 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047871 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051165 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041934 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041078 has 2 parents
# http://lod.gesis.org/thesoz/concept_10058469 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038009 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035910 has 3 parents
# http://lod.gesis.org/thesoz/concept_10049613 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039601 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044179 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046764 has 2 parents
# http://lod.gesis.org/thesoz/concept_10061879 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043624 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041835 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040330 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041038 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038892 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042328 has 3 parents
# http://lod.gesis.org/thesoz/concept_10038098 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036886 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035866 has 4 parents
# http://lod.gesis.org/thesoz/concept_10042337 has 3 parents
# http://lod.gesis.org/thesoz/concept_10083135 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041634 has 4 parents
# http://lod.gesis.org/thesoz/concept_10044182 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034511 has 3 parents
# http://lod.gesis.org/thesoz/concept_10042335 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042743 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037337 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042035 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037292 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038507 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035647 has 3 parents
# http://lod.gesis.org/thesoz/concept_10039580 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046872 has 2 parents
# http://lod.gesis.org/thesoz/concept_10055821 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044502 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046874 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043497 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044331 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037644 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034497 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042350 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038169 has 2 parents
# http://lod.gesis.org/thesoz/concept_10082944 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042321 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035238 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043230 has 2 parents
# http://lod.gesis.org/thesoz/concept_10050115 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037927 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035356 has 2 parents
# http://lod.gesis.org/thesoz/concept_10047872 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038250 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037545 has 2 parents
# http://lod.gesis.org/thesoz/concept_10049695 has 2 parents
# http://lod.gesis.org/thesoz/concept_10060105 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036481 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041643 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036536 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036846 has 3 parents
# http://lod.gesis.org/thesoz/concept_10043468 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042078 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041873 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035323 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042319 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035258 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040878 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042111 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041529 has 2 parents
# http://lod.gesis.org/thesoz/concept_10079950 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042367 has 3 parents
# http://lod.gesis.org/thesoz/concept_10074906 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051536 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040911 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042342 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036365 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037371 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042317 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046232 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039923 has 2 parents
# http://lod.gesis.org/thesoz/concept_10037409 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042047 has 2 parents
# http://lod.gesis.org/thesoz/concept_10034370 has 2 parents
# http://lod.gesis.org/thesoz/concept_10038218 has 2 parents
# http://lod.gesis.org/thesoz/concept_10039567 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042334 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035888 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045291 has 2 parents
# http://lod.gesis.org/thesoz/concept_10046887 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035761 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035889 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042369 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035022 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035891 has 2 parents
# http://lod.gesis.org/thesoz/concept_10041660 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045287 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042332 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035063 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043315 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042363 has 3 parents
# http://lod.gesis.org/thesoz/concept_10035557 has 2 parents
# http://lod.gesis.org/thesoz/concept_10035160 has 2 parents
# http://lod.gesis.org/thesoz/concept_10045433 has 2 parents
# http://lod.gesis.org/thesoz/concept_10079537 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040345 has 2 parents
# http://lod.gesis.org/thesoz/concept_10036146 has 2 parents
# http://lod.gesis.org/thesoz/concept_10042897 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043484 has 2 parents
# http://lod.gesis.org/thesoz/concept_10040200 has 2 parents
# http://lod.gesis.org/thesoz/concept_10051331 has 2 parents
# http://lod.gesis.org/thesoz/concept_10043634 has 2 parents
# http://lod.gesis.org/thesoz/concept_10044178 has 2 parents
